# %%
# 코드 슬라이스 추출 전, 작업에 필요한 디렉토리 구조를 만들기 위한 코드
# label_info 파일의 첫 컬럼을 읽고, 그에 해당하는 이름의 디렉토리를 지정한 위치에 생성한다.

import os
import csv
import re

# 불필요한 접미사를 제거하는 함수
def clean_filename(file_name: str) -> str:
    return re.sub(r'(_01|_)$', '', file_name)  # "_01" 또는 "_"로 끝나면 제거

# label_info 파일의 첫 번째 컬럼에서 카테고리명을 추출하는 함수
def extract_sard_category_name(label_info_file: str):
    category_names = set()  # 중복 제거를 위해 set 사용
    
    with open(label_info_file, "r", encoding="utf-8") as infile:
        reader = csv.reader(infile)
        next(reader, None)  # 첫 번째 줄(헤더) 건너뛰기
        
        for row in reader:
            if len(row) < 1:  # 첫 번째 컬럼이 없는 경우 건너뛰기
                continue       
            
            file_name = row[0].strip()
            if file_name:  # 빈 문자열이 아닐 경우에만 추가
                cleaned_name = clean_filename(file_name)  # 정리된 파일명 사용
                category_names.add(cleaned_name)

    return list(category_names)  # set을 다시 리스트로 변환하여 반환

# 디렉터리 생성 함수
def create_directories(base_path: str, category_names: list):
    for category in category_names:
        category_path = os.path.join(base_path, category)
        
        if os.path.exists(category_path):  # 이미 존재하면 건너뜀
            print(f"건너뜀: {category_path} (이미 존재)")
            continue
        
        try:
            os.makedirs(category_path, exist_ok=True)
            print(f"디렉터리 생성 완료: {category_path}")
        except Exception as e:
            print(f"디렉터리 생성 실패: {category_path}, 오류: {e}")

# main 실행
def main():
    base_directory = "./r_dirs_test"  # 작업할 디렉토리
    label_info_directory = "./label_info_files_directory" 
    label_info_file = os.path.join(label_info_directory, "SARD_Sink_Resource_v0.3_250317.csv")  # labelinfo로 사용할 csv 파일 지정정
    
    if not os.path.exists(label_info_file):
        print(f"오류: {label_info_file} 파일이 존재하지 않습니다.")
        return
    
    categories = extract_sard_category_name(label_info_file)
    create_directories(base_directory, categories)

# 실행
if __name__ == "__main__":
    main()
# Out:
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_struct_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fputc
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__open_w32CloseHandle
# 디렉터리 생성 완료: ./r_dirs_test\CWE775_Missing_Release_of_File_Descriptor_or_Handle__open_no_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_class_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_long_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_connect_socket
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__malloc_delete_array_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fgets
# 디렉터리 생성 완료: ./r_dirs_test\CWE773_Missing_Reference_to_Active_File_Descriptor_or_Handle__fopen
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__char_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_file
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_char_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int64_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_putc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__calloc_delete_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__w32_RpcImpersonateClient
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_long_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_struct_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_class_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__char_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_w32CreateMutex
# 디렉터리 생성 완료: ./r_dirs_test\CWE675_Duplicate_Operations_on_Resource__freopen
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__calloc_delete_array_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_environment
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int64_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int64_t_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_struct_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_puts
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_struct_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_long_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_wchar_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fread
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fwrite
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__freopen_w32_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_snprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int64_t_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_console
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fgets
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_class_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fputs
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_TwoIntsClass
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__wchar_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fputc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int64_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_sscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fputs
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__return_freed_ptr
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_char_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_struct_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__wchar_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_long_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__w32ImpersonateSelf
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_remove
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_wchar_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_console
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_puts
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_struct_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_class_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_sscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_struct_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__malloc_realloc_struct_twoIntsStruct
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_class_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__struct_twoIntsStruct_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__no_assignment_op_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE675_Duplicate_Operations_on_Resource__w32CreateFile
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_class_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__calloc_delete_array_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__no_copy_const_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_w32CreateMutex
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_long_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__malloc_delete_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_struct_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_char_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_array_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int64_t_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_char_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_w32CreateNamedPipe
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fwrite
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_putc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__strdup_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_long_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__malloc_realloc_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_char_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_puts
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__malloc_realloc_twoIntsStruct
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__char_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_char_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__w32CreateFile_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fgets
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_char_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_struct_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int64_t_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_struct_twoIntsStruct
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_w32ImpersonateNamedPipeClient
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_remove
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_putc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int64_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_char_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_TwoIntsClass
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__realloc_delete_array_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__twoIntsStruct_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_long_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int64_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_connect_socket
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_class_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_char_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_long_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__twoIntsStruct_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__no_copy_const_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__fopen_w32CloseHandle
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_char_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fputc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_wchar_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_struct_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fwrite
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__w32CreateFile_fclose
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_char_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_remove
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_long_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__realloc_delete_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__struct_twoIntsStruct_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_wchar_t_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_fixed_string
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__malloc_delete_array_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_class_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_wchar_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_char_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE775_Missing_Release_of_File_Descriptor_or_Handle__fopen_no_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_long_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int64_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_long_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_wchar_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_w32CreateMutex
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int64_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE773_Missing_Reference_to_Active_File_Descriptor_or_Handle__w32CreateFile
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int64_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_fixed_string
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_wchar_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_putchar
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_w32CreateNamedPipe
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_w32CreateMutex
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__realloc_delete_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_putc
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int64_t_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_wchar_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_putchar
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_puts
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_struct_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_char_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_array_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_array_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_snprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__realloc_delete_array_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_wchar_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_file
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fread
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_array_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_twointsStruct
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_putchar
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_wchar_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__fopen_w32_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_long_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_remove
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__no_assignment_op_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int64_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE773_Missing_Reference_to_Active_File_Descriptor_or_Handle__open
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__malloc_realloc_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int64_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int64_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_putchar
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__malloc_free_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_snprintf
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__int_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__open_fclose
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_class_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__wchar_t_listen_socket
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_class_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE675_Duplicate_Operations_on_Resource__open
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__strdup_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_fwrite
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__strdup_delete_array_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE675_Duplicate_Operations_on_Resource__fopen
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fputs
# 디렉터리 생성 완료: ./r_dirs_test\CWE404_Improper_Resource_Shutdown__freopen_w32CloseHandle
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_class_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_char_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_class_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_scanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int64_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int64_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_listen_socket
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_w32CreateNamedPipe
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_wchar_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_rename
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_struct_twoIntsStruct
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_array_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_char_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fputc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_int_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__malloc_realloc_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_int_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_wchar_t_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_int_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE761_Free_Pointer_Not_at_Start_of_Buffer__char_environment
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_wchar_t_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_fread
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_array_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_scanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_w32ImpersonateNamedPipeClient
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__struct_twoIntsStruct_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_int_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_wchar_t_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_fread
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_struct
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_delete_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__w32_ImpersonateSelf
# 디렉터리 생성 완료: ./r_dirs_test\CWE416_Use_After_Free__new_delete_int64_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_scanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_wchar_t
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_long_declare
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_struct_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_class_calloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_class
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__calloc_delete_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_long_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_delete_array_char
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_free_01_bad
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__malloc_delete_01_good1
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_fgets
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__wchar_t_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_struct_placement_new
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_struct_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_struct_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__char_rename
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__twoIntsStruct_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_struct_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_rename
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_long_malloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_wchar_t_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_long_realloc
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_sscanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__delete_array_char_static
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_scanf
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__new_array_free_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__malloc_free_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE415_Double_Free__new_delete_long
# 디렉터리 생성 완료: ./r_dirs_test\CWE762_Mismatched_Memory_Management_Routines__delete_array_wchar_t_reallo
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__char_rename
# 디렉터리 생성 완료: ./r_dirs_test\CWE590_Free_Memory_Not_on_Heap__free_int64_t_alloca
# 디렉터리 생성 완료: ./r_dirs_test\CWE775_Missing_Release_of_File_Descriptor_or_Handle__w32CreateFile_no_close
# 디렉터리 생성 완료: ./r_dirs_test\CWE253_Incorrect_Check_of_Function_Return_Value__wchar_t_w32CreateNamedPipe
# 디렉터리 생성 완료: ./r_dirs_test\CWE401_Memory_Leak__new_int
# 디렉터리 생성 완료: ./r_dirs_test\CWE252_Unchecked_Return_Value__wchar_t_snprintf
